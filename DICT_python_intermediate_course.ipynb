# %%
class Customers:
  greeting = "Welcome to Coffee Palace!"
  def __init__ (self, name, beverage, food, total):
    self.name = name
    self.beverage = beverage
    self.food = food
    self.total = total
c_1 = Customers("Nate", "Espresso", "Pastrami on rye", 220)
c_2 = Customers("Elaine", "Strawberry frappuccino", "Tuna Wrap", 270)
C_3 = Customers("Samirah", "Iced caffe latte", "Cinnamon roll", 225)
c_4 = Customers("Jerry", "Caramel macchiato", "Glazed doughnut", 230)
c_5 = Customers("Paz", "Iced tea", "Blueberry pancakes", 315)

print(Customers.greeting)
print(c_2.name)
print(c_2.beverage)
print(c_2.food)
print(c_2.total)
print(c_4.name)
print(c_4.beverage)
print(c_4.food)
print(c_4.total)
# Out:
# Welcome to Coffee Palace!
# Elaine
# Strawberry frappuccino
# Tuna Wrap
# 270
# Jerry
# Caramel macchiato
# Glazed doughnut
# 230

# %%
class ClubMembers:
  def __init__(self, name, birthday, age, favorite_food, goal):
    self.name = name
    self.birthday = birthday
    self.age = age
    self.favorite_food = favorite_food
    self.goal = goal

  def display1(self):
    print("name: ", self.name)
    print("birthday: ", self.birthday)
    print("age: ", self.age)
    print("favorite food: ", self.favorite_food)
    print("goal: ", self.goal)

class ClubOfficers(ClubMembers):
  def __init__(self, name, birthday, age, favorite_food, goal, position):
    self.position = position
    ClubMembers.__init__(self, name, birthday, age, favorite_food, goal)
  
  def display2(self):
    print("name: ", self.name)
    print("birthday: ", self.birthday)
    print("age: ", self.age)
    print("favorite food: ", self.favorite_food)
    print("goal: ", self.goal)
    print("position: ", self.position)

m_1 = ClubMembers("Tom", "January 16", 14, "Ice cream", "To be happy")
o_4 = ClubOfficers("Vera", "June 22", 16, "Beef stroganoff", "To be the world's greatest chef", "Treasurer")

m_1.display1()
o_4.display2()
# Out:
# name:  Tom
# birthday:  January 16
# age:  14
# favorite food:  Ice cream
# goal:  To be happy
# name:  Vera
# birthday:  June 22
# age:  16
# favorite food:  Beef stroganoff
# goal:  To be the world's greatest chef
# position:  Treasurer

# %%
flavors = ["vanilla", "chocolate", "strawberry", "cookies n' cream", "bubblegum"]
toppings = ["almonds", "banana slices", "chocolate syrup", "caramel syrup", "white chocolate chips"]

ice_cream = dict(zip(flavors, toppings))
print(ice_cream)

ice_cream["chocolate"] = "blueberries"
print(ice_cream)

ice_cream.update({"matcha" : "pistachios", "ube" : "mango slices"})
print(ice_cream)
# Out:
# {'vanilla': 'almonds', 'chocolate': 'banana slices', 'strawberry': 'chocolate syrup', "cookies n' cream": 'caramel syrup', 'bubblegum': 'white chocolate chips'}
# {'vanilla': 'almonds', 'chocolate': 'blueberries', 'strawberry': 'chocolate syrup', "cookies n' cream": 'caramel syrup', 'bubblegum': 'white chocolate chips'}
# {'vanilla': 'almonds', 'chocolate': 'blueberries', 'strawberry': 'chocolate syrup', "cookies n' cream": 'caramel syrup', 'bubblegum': 'white chocolate chips', 'matcha': 'pistachios', 'ube': 'mango slices'}

# %%
groceries = {"chicke" : 8, "apples" : 6, "cucumbers" : 3, "milk" : 2, "oranges" : 4}
erase = groceries.pop("oranges")

print(groceries)
# Out:
# {'chicke': 8, 'apples': 6, 'cucumbers': 3, 'milk': 2}

# %%
speakers = {"Sir Rafael" : 54, "Ms. Joan" : 33, "Ms. Dana" : 67}
names = speakers.keys()

print(names)

tryout = {"Carl" : "passed", "Quentin" : "failed", "John Y." : "passed", "Peter" : "failed", "Max T." : "passed", "Joseph" : "passed", "Jone" : "failed", "Jorge" : "failed", "George" : "passed", "Ben" : "passed", "Jerome" : "passed", "Rick" : "failed", "Max G." : "failed", "John P." : "failed", "Vince" : "passed"}
check = tryout.get("Jorge")

print(check)
# Out:
# dict_keys(['Sir Rafael', 'Ms. Joan', 'Ms. Dana'])
# failed

# %%
file = open("new.txt" , "w")
file.write("I like python because it is easy")

file = open("new.txt" , "a")
file.write("\nDo some more python")
file.write("\nMake projects")
file.write("\nBe excellent at python")

file = open("new.txt" , "r")
apple = file.read()
print(apple)
file.close()
# Out:
# I like python because it is easy
# Do some more python
# Make projects
# Be excellent at python

# %%
file = open("new.txt" , "r")
print(file.read())

file = open("new.txt" , "r")
print(file.readline())

file = open("new.txt" , "r")
for x in file:
  print(x)

import os
if os.path.exists("new.txt"):
  os.remove("new.txt")
else:
  print("File does not exist")
# Out:
# I like python because it is easy
# Do some more python
# Make projects
# Be excellent at python
# I like python because it is easy
#
# I like python because it is easy
#
# Do some more python
#
# Make projects
#
# Be excellent at python

# %%
#Lesson on how to raise exceptions on purpose
x = 500
if x > 100:
  raise Exception("Exceeds 100")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-4a12319d2772> in <module>()
#       1 x = 500
#       2 if x > 100:
# ----> 3   raise Exception("Exceeds 100")
#       4
#
# Exception: Exceeds 100

# %%
try:
  print(variable_1)

except:
  print("variable_1 not defined")
# Out:
# variable_1 not defined

# %%
for i in range(6):
  print("I'm so hapy!")
# Out:
# I'm so hapy!
# I'm so hapy!
# I'm so hapy!
# I'm so hapy!
# I'm so hapy!
# I'm so hapy!

# %%
try:
  print(12 * 6)
except:
  print("Invalid operation")
else:
  print("Valid operation")
# Out:
# 72
# Valid operation

# %%
#Lesson on how to incur an AssertionError on purpose
best_burger = "Burger King"
number_2_burger = "McDonald's"

assert number_2_burger == "McDonald's"
assert number_2_burger == "Jollibee"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-fc64316dc5fe> in <module>()
#       4
#       5 assert number_2_burger == "McDonald's"
# ----> 6 assert number_2_burger == "Jollibee"
#
# AssertionError:

# %%
f = open("functionfile.py" , "x")

# %%
from functionfile import getsum
from functionfile import sayHello

sum = getsum(1, 9)
print(sum)
sayHello()
# Out:
# 10
# Hello!

# %%
help("modules")

# %%
help("random")

# %%
from random import randint

print(int(randint(1,100)))
# Out:
# 88
